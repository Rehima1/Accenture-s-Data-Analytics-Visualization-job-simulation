# %% [markdown]
# <a href="https://colab.research.google.com/github/Rehima1/Accenture-s-Data-Analytics-Visualization-job-simulation/blob/main/TaskTwo__Accenture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('Content.csv')

# %%
import pandas as pd
data1 = pd.read_csv('Reactions.csv')

# %%
import pandas as pd
data2 = pd.read_csv('ReactionTypes.csv')

# %%
data.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2           2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3           3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4           4  01ab84dd-6364-4236-abbb-3f237db77180
#
#                                 User ID   Type        Category  \
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo        Studying
# 1  beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo  healthy eating
# 2  a5c65404-5894-4b87-82f2-d787cbee86b4  photo  healthy eating
# 3  9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo      technology
# 4  e206e31b-5f85-4964-b6ea-d7ee5324def1  video            food
#
#                                                  URL
# 0  https://socialbuzz.cdn.com/content/storage/975...
# 1  https://socialbuzz.cdn.com/content/storage/9f7...
# 2  https://socialbuzz.cdn.com/content/storage/230...
# 3  https://socialbuzz.cdn.com/content/storage/356...
# ...

# %%
data1.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2           2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3           3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4           4  97522e57-d9ab-4bd6-97bf-c24d952602d2
#
#                                 User ID     Type             Datetime
# 0                                   NaN      NaN  2021-04-22 15:17:15
# 1  5d454588-283d-459d-915d-c48a2cb4c27f  disgust  2020-11-07 09:43:50
# 2  92b87fa5-f271-43e0-af66-84fac21052e6  dislike  2021-06-17 12:22:51
# 3  163daa38-8b77-48c9-9af6-37a6c1447ac2   scared  2021-04-18 05:13:58
# 4  34e8add9-0206-47fd-a501-037b994650a2  disgust  2021-01-06 19:13:01

# %%
data2.head()
# Out:
#    Unnamed: 0        Type Sentiment  Score
# 0           0       heart  positive     60
# 1           1        want  positive     70
# 2           2     disgust  negative      0
# 3           3        hate  negative      5
# 4           4  interested  positive     30

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1000 non-null   int64
#  1   Content ID  1000 non-null   object
#  2   User ID     1000 non-null   object
#  3   Type        1000 non-null   object
#  4   Category    1000 non-null   object
#  5   URL         801 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 47.0+ KB

# %%
data['Type'] = data['Type'].astype('string')
data['Category'] = data['Category'].astype('string')
data['URL'] = data['URL'].astype('string')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1000 non-null   int64
#  1   Content ID  1000 non-null   object
#  2   User ID     1000 non-null   object
#  3   Type        1000 non-null   string
#  4   Category    1000 non-null   string
#  5   URL         801 non-null    string
# dtypes: int64(1), object(2), string(3)
# memory usage: 47.0+ KB

# %%
data = data.drop(columns=['URL','User ID'], errors='ignore')

# %%
print(data.columns)
# Out:
# Index(['Unnamed: 0', 'Content ID', 'Type', 'Category'], dtype='object')

# %%
data = data.rename(columns= {'Type': 'Content Type'})

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25553 entries, 0 to 25552
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  25553 non-null  int64
#  1   Content ID  25553 non-null  object
#  2   User ID     22534 non-null  object
#  3   Type        24573 non-null  object
#  4   Datetime    25553 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 998.3+ KB

# %%
data1['Type'] = data1['Type'].astype('string')
data1['Datetime'] = pd.to_datetime(data1['Datetime'])

# %%
data1.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2           2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3           3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4           4  97522e57-d9ab-4bd6-97bf-c24d952602d2
#
#                                 User ID     Type            Datetime
# 0                                   NaN     <NA> 2021-04-22 15:17:15
# 1  5d454588-283d-459d-915d-c48a2cb4c27f  disgust 2020-11-07 09:43:50
# 2  92b87fa5-f271-43e0-af66-84fac21052e6  dislike 2021-06-17 12:22:51
# 3  163daa38-8b77-48c9-9af6-37a6c1447ac2   scared 2021-04-18 05:13:58
# 4  34e8add9-0206-47fd-a501-037b994650a2  disgust 2021-01-06 19:13:01

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25553 entries, 0 to 25552
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  25553 non-null  int64
#  1   Content ID  25553 non-null  object
#  2   User ID     22534 non-null  object
#  3   Type        24573 non-null  string
#  4   Datetime    25553 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2), string(1)
# memory usage: 998.3+ KB

# %%
print(data1.columns)
# Out:
# Index(['Unnamed: 0', 'Content ID', 'User ID', 'Type', 'Datetime'], dtype='object')

# %%
data1.columns = data1.columns.str.strip()
data1 = data1.drop(columns=['User ID'], errors='ignore')

# %%
print(data1.columns)
# Out:
# Index(['Unnamed: 0', 'Content ID', 'Type', 'Datetime'], dtype='object')

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  16 non-null     int64
#  1   Type        16 non-null     object
#  2   Sentiment   16 non-null     object
#  3   Score       16 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 640.0+ bytes

# %%
data2['Type'] = data2['Type'].astype('string')
data2['Sentiment'] = data2['Sentiment'].astype('string')

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  16 non-null     int64
#  1   Type        16 non-null     string
#  2   Sentiment   16 non-null     string
#  3   Score       16 non-null     int64
# dtypes: int64(2), string(2)
# memory usage: 640.0 bytes

# %%
data.isnull().sum()
# Out:
# Unnamed: 0      0
# Content ID      0
# Content Type    0
# Category        0
# dtype: int64

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# Unnamed: 0      0
# Content ID      0
# Content Type    0
# Category        0
# dtype: int64

# %%
data1.isnull().sum()
# Out:
# Unnamed: 0      0
# Content ID      0
# Type          980
# Datetime        0
# dtype: int64

# %%
data1 = data1.dropna()

# %%
data1.isnull().sum()
# Out:
# Unnamed: 0    0
# Content ID    0
# Type          0
# Datetime      0
# dtype: int64

# %%
data2.isnull().sum()
# Out:
# Unnamed: 0    0
# Type          0
# Sentiment     0
# Score         0
# dtype: int64

# %%
data.drop_duplicates()
# Out:
#      Unnamed: 0                            Content ID Content Type  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810        photo
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f        photo
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6        photo
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180        video
# ..          ...                                   ...          ...
# 995         995  b4cef9ef-627b-41d7-a051-5961b0204ebb        video
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c          GIF
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b        audio
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7          GIF
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56        audio
#
#             Category
# 0           Studying
# 1     healthy eating
# 2     healthy eating
# 3         technology
# 4               food
# ..               ...
# ...

# %%
data1.drop_duplicates()
# Out:
#        Unnamed: 0                            Content ID        Type  \
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2     dislike
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2      scared
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# 5               5  97522e57-d9ab-4bd6-97bf-c24d952602d2  interested
# ...           ...                                   ...         ...
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56     dislike
# 25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56   intrigued
# 25550       25550  75d6b589-7fae-4a6d-b0d0-752845150e56  interested
# 25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56     worried
# 25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56     cherish
#
#                  Datetime
# 1     2020-11-07 09:43:50
# 2     2021-06-17 12:22:51
# 3     2021-04-18 05:13:58
# 4     2021-01-06 19:13:01
# ...

# %%
data2.drop_duplicates()
# Out:
#     Unnamed: 0         Type Sentiment  Score
# 0            0        heart  positive     60
# 1            1         want  positive     70
# 2            2      disgust  negative      0
# 3            3         hate  negative      5
# 4            4   interested  positive     30
# 5            5  indifferent   neutral     20
# 6            6         love  positive     65
# 7            7   super love  positive     75
# 8            8      cherish  positive     70
# 9            9        adore  positive     72
# 10          10         like  positive     50
# 11          11      dislike  negative     10
# 12          12    intrigued  positive     45
# 13          13      peeking   neutral     35
# 14          14       scared  negative     15
# 15          15      worried  negative     12

# %%
data.shape
# Out:
# (1000, 4)

# %%
data1.shape
# Out:
# (24573, 4)

# %%
data2.shape
# Out:
# (16, 4)

# %%
from google.colab import files

data.to_csv('cleaned_data.csv', index=False)

# Download the file
files.download('cleaned_data.csv')

# %%
data1.to_csv('cleaned_data1.csv', index=False)

# Download the file
files.download('cleaned_data1.csv')

# %%
data2.to_csv('cleaned_data2.csv', index=False)

# Download the file
files.download('cleaned_data2.csv')

# %% [markdown]
# # **Merging datasets**

# %%
merged_data = pd.merge(data2, data1, on = 'Type', how = 'inner' )

# %%
merged_data = pd.merge(merged_data, data, on='Content ID', how='inner')

# %%
merged_data.to_csv('merged_data.csv', index=False)

# Download the file
files.download('merged_data.csv')

# %% [markdown]
# # **Modelling**

# %%
import pandas as pd
data3 = pd.read_csv('merged_data.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
category_scores = data3.groupby('Category')['Score'].sum().reset_index()

category_scores = category_scores.sort_values(by='Score', ascending=False)

top_5_category_scores = category_scores.head(5)

print(top_5_category_scores)
# Out:
#           Category  Score
# 24         animals  69548
# 31  healthy eating  69067
# 36      technology  67472
# 33         science  66043
# 25         cooking  63982

# %%
plt.figure(figsize = (8 ,6))
sns.barplot(data = top_5_categories , x ='Category', y = 'Score', palette='Set2')
plt.title('Top 5 Performing Categories')
plt.xlabel('Category')
plt.ylabel('Total Score')
plt.show
# Out:
# <ipython-input-53-33288c8c56de>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = top_5_categories , x ='Category', y = 'Score', palette='Set2')
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(8, 6))

plt.pie(
    top_5_categories['Score'],
    labels=top_5_categories['Category'],
    autopct='%1.1f%%',
    colors=sns.color_palette('viridis', n_colors=len(top_5_categories))
)

plt.title('Top 5 Performing Categories')

plt.show()
